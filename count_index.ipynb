# %%
s = "mohammed"
count = 0
for i in range(len(s)):
    if s[i] == "m":
        count += 1
print(count)
# Out:
# 3

# %%
s = "mohammed"
count = 0
for i in range(len(s)):
    if s[i] == "m":
        print(i)
# Out:
# 0
# 4
# 5
